# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %matplotlib inline

# %%
covidtests = pd.read_csv('../COVID-19/data_tables/testing_data/time_series_covid19_US.csv')

# %%
covidtests = covidtests.loc[covidtests.state == 'NY']
covidtests
# Out:
#             date state  cases_conf_probable  cases_confirmed  cases_probable  \
# 22327   3/2/2020    NY                  0.0              NaN             NaN
# 22328   3/3/2020    NY                  1.0              NaN             NaN
# 22329   3/4/2020    NY                  1.0              NaN             NaN
# 22330   3/5/2020    NY                  3.0              NaN             NaN
# 22331   3/6/2020    NY                 25.0              NaN             NaN
# ...          ...   ...                  ...              ...             ...
# 35937  12/3/2021    NY            2734874.0        2734874.0             0.0
# 35993  12/4/2021    NY            2744781.0        2744781.0             0.0
# 36049  12/5/2021    NY            2755192.0        2755192.0             0.0
# 36105  12/6/2021    NY            2761270.0        2761270.0             0.0
# 36161  12/7/2021    NY            2769480.0        2769480.0             0.0
#
# ...

# %%
covidtests.to_csv('../data/nycovidtests.csv')

# %%
covidvaccine = pd.read_csv('../COVID-19/data_tables/vaccine_data/us_data/time_series/people_vaccinated_us_timeline.csv')

# %%
covidvaccine = covidvaccine.loc[covidvaccine['Province_State'] ==  'New York']
covidvaccine
# Out:
#        FIPS Province_State Country_Region        Date      Lat    Long_  \
# 13743  36.0       New York             US  2020-12-10  42.1657 -74.9481
# 13744  36.0       New York             US  2020-12-11  42.1657 -74.9481
# 13745  36.0       New York             US  2020-12-12  42.1657 -74.9481
# 13746  36.0       New York             US  2020-12-13  42.1657 -74.9481
# 13747  36.0       New York             US  2020-12-14  42.1657 -74.9481
# ...     ...            ...            ...         ...      ...      ...
# 14101  36.0       New York             US  2021-12-03  42.1657 -74.9481
# 14102  36.0       New York             US  2021-12-04  42.1657 -74.9481
# 14103  36.0       New York             US  2021-12-05  42.1657 -74.9481
# 14104  36.0       New York             US  2021-12-06  42.1657 -74.9481
# 14105  36.0       New York             US  2021-12-07  42.1657 -74.9481
#
#        Combined_Key  People_Fully_Vaccinated  People_Partially_Vaccinated
# ...

# %%
covidvaccine.to_csv('../data/nycovidvaccine.csv')

# %%
vaccinedoses = pd.read_csv('../COVID-19/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv')

# %%
vaccinedoses = vaccinedoses.loc[vaccinedoses['Province_State'] == 'New York']
vaccinedoses
# Out:
#       Province_State        Date Vaccine_Type  FIPS Country_Region      Lat  \
# 74915       New York  2020-12-10          All  36.0             US  42.1657
# 74916       New York  2020-12-10      Moderna  36.0             US  42.1657
# 74917       New York  2020-12-10       Pfizer  36.0             US  42.1657
# 74918       New York  2020-12-11          All  36.0             US  42.1657
# 74919       New York  2020-12-11      Moderna  36.0             US  42.1657
# ...              ...         ...          ...   ...            ...      ...
# 76858       New York  2021-12-07       Pfizer  36.0             US  42.1657
# 76859       New York  2021-12-07      Moderna  36.0             US  42.1657
# 76860       New York  2021-12-07      Unknown  36.0             US  42.1657
# 76861       New York  2021-12-07          All  36.0             US  42.1657
# 76862       New York  2021-12-07   Unassigned  36.0             US  42.1657
#
# ...

# %%
vaccinedoses.to_csv('../data/nyvaccinedoses.csv')

# %%
nyboroughsinfections = pd.read_csv('../COVID-19/data_tables/Data_for_UScounty_map/NY_Boroughs_Confirmed.csv')

# %%
nyboroughsinfections
# Out:
#    Unnamed: 0   FIPS    Admin2 Province_State Country_Region  4/14/20  \
# 0           0  36005     Bronx       New York             US    23426
# 1           1  36047     Kings       New York             US    28183
# 2           2  36061  New York       New York             US    13740
# 3           3  36081    Queens       New York             US    33616
# 4           4  36085  Richmond       New York             US     8236
#
#    4/15/20  4/16/20  4/17/20  4/18/20  ...  10/30/20  10/31/20  11/1/20  \
# 0    24587    25638    27014    28016  ...     55408     55501    55621
# 1    29250    31279    32499    33729  ...     73409     73597    73772
# 2    14188    15539    15952    16404  ...     33609     33714    33818
# 3    34831    36220    37447    38733  ...     75814     75995    76133
# 4     8504     8822     9166     9414  ...     16888     16962    17010
#
#    11/2/20  11/3/20  11/4/20  11/5/20  11/6/20  11/7/20  11/8/20
# ...

# %%
nyboroughsinfections.to_csv('../data/nyboroughsconfirmed.csv')

# %%
nyboroughsdeaths = pd.read_csv('../COVID-19/data_tables/Data_for_UScounty_map/NY_Boroughs_Deaths.csv')

# %%
nyboroughsdeaths
# Out:
#    Unnamed: 0   FIPS    Admin2 Province_State Country_Region  4/14/20  \
# 0           0  36005     Bronx       New York             US     1512
# 1           1  36047     Kings       New York             US     1869
# 2           2  36061  New York       New York             US      756
# 3           3  36081    Queens       New York             US     2105
# 4           4  36085  Richmond       New York             US      345
#
#    4/15/20  4/16/20  4/17/20  4/18/20  ...  10/30/20  10/31/20  11/1/20  \
# 0     1584     1749     1802     1917  ...      4060      4061     4063
# 1     1954     2189     2293     2490  ...      5753      5754     5757
# 2      771      927     1004     1088  ...      2550      2550     2552
# 3     2179     2324     2402     2543  ...      6062      6062     6063
# 4      349      369      385      406  ...       910       910      910
#
#    11/2/20  11/3/20  11/4/20  11/5/20  11/6/20  11/7/20  11/8/20
# ...

# %%
nyboroughsdeaths.to_csv('../data/nyboroughsdeaths.csv')
